# %%
# !pip3 install ortools &> /dev/null
# !pip3 install wandb   &> /dev/null

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: edsonroteia. Use `wandb login --relogin` to force relogin

# %%
import os
os.chdir("/content/drive/MyDrive/reimplementation-masters")

# %%
# %run main.py --model_type PVT --epochs 7500 --lr 5e-4
# %run main.py --model_type PVTAudioSeqSeparateMLPs --epochs 3000 --lr 1e-5
# %run main.py --model_type PVTAudio --epochs 7500 --lr 5e-4
# %run main.py --model_type PVTAudioSeq --epochs 325 --lr 5e-4

# %run main.py --model_type PVT --epochs 7500 --lr 5e-3
# %run main.py --model_type PVTAudio --epochs 7500 --lr 5e-3
# %run main.py --model_type PVTAudioSeq --epochs 7500 --lr 5e-3
# Out:
# wandb: Currently logged in as: edsonroteia. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.0
# Run data is saved locally in <code>/content/drive/MyDrive/reimplementation-masters/wandb/run-20240527_134250-1nylnc7v</code>
# Syncing run <strong><a href='https://wandb.ai/edsonroteia/reimplementation/runs/1nylnc7v' target="_blank">devout-frog-270</a></strong> to <a href='https://wandb.ai/edsonroteia/reimplementation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/edsonroteia/reimplementation' target="_blank">https://wandb.ai/edsonroteia/reimplementation</a>
#  View run at <a href='https://wandb.ai/edsonroteia/reimplementation/runs/1nylnc7v' target="_blank">https://wandb.ai/edsonroteia/reimplementation/runs/1nylnc7v</a>
# Using device: cuda
# [SumMe] Training on split0:
# ...

# %%
import ortools
from ortools.algorithms.python import knapsack_solver as kps
dir(kps.KnapsackSolver(kps.KNAPSACK_DYNAMIC_PROGRAMMING_SOLVER,'test'))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'best_solution_contains',
#  'init',
#  'is_solution_optimal',
#  'set_time_limit',
#  'set_use_reduction',
#  'solve']

# %%
ortools.algorithms.python.knapsack_solver.K
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6bcd6fd6caa6> in <cell line: 1>()
# ----> 1 ortools.algorithms.python.knapsack_solver.K
#
# AttributeError: module 'ortools.algorithms.python.knapsack_solver' has no attribute 'K'
